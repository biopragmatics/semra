# %%
from semra.landscape.genes import CONFIGURATION
from semra.landscape.utils import notebook

# %%
_ = notebook(CONFIGURATION, output_directory=".")
# Out:
# ## Summarize the Resources
#
# We summarize the resources used in the landscape analysis, including their [Bioregistry](https://bioregistry.io)
# prefix, license, current version, and number of terms (i.e., named concepts) they contain.
# 1 resources were not available through
# [PyOBO](https://github.com/biopragmatics/pyobo). Therefore, we estimate the number
# of terms in that resource based on the ones appearing in mappings. Note that these
# are typically an underestimate.
#                                                         name  \
# prefix
# ncbigene                                         Entrez Gene
# hgnc                        HUGO Gene Nomenclature Committee
# mgi                                 Mouse Genome Informatics
# rgd                                      Rat Genome Database
# cgnc                    Chicken Gene Nomenclature Consortium
# wormbase                                       Wormbase Gene
# flybase                                         FlyBase Gene
# sgd                            Saccharomyces Genome Database
# omim                     Online Mendelian Inheritance in Man
# civic.gid                                         CIViC gene
# umls       Unified Medical Language System Concept Unique...
# ncit                                           NCI Thesaurus
# wikidata                                            Wikidata
#
#                                                      license         version  \
# prefix
# ncbigene                                                None           daily
# hgnc                                                 CC0-1.0      2024-03-01
# mgi                                                CC-BY-4.0            6.23
# rgd                                                CC-BY-4.0      2024-03-22
# cgnc                                                    None            None
# wormbase                                             CC0-1.0            None
# flybase                                            CC-BY-4.0         2024_01
# sgd                                                CC-BY-4.0         R64-3-1
# omim                     https://www.omim.org/help/agreement  April 10, 2024
# civic.gid                                            CC0-1.0     01-Apr-2024
# umls       https://www.nlm.nih.gov/research/umls/knowledg...          2023AB
# ncit                                               CC-BY-4.0          24.02d
# wikidata                                             CC0-1.0            None
#
#               terms    status
# prefix
# ncbigene   47782242      full
# hgnc          43865      full
# mgi          682164      full
# rgd           61339      full
# cgnc          25936      full
# wormbase          0  observed
# flybase       17883      full
# sgd            6600      full
# omim          26954  observed
# civic.gid       506      full
# umls              1    subset
# ncit          12311    subset
# wikidata     797966  observed
# There are a total of 49,457,767 terms across the 13 resources.
# ## Summarize the Mappings
#
# In order to summarize the mappings, we're going to load them, index them, and count
# the number of mappings between each pair of resources. The self-mapping column is
# the count of terms in the resource. We'll do this to the raw mappings first, then
# to the processed mappings, then compare them.
# Indexing mappings:   0%|          | 0.00/1.61M [00:00<?, ?mapping/s]
# Indexing mappings:   0%|          | 0.00/3.61M [00:00<?, ?mapping/s]
# First, we summarize the raw mappings, i.e., the mappings that are directly available from the sources
# target_prefix  ncbigene   hgnc     mgi    rgd   cgnc  wormbase  flybase   sgd  \
# source_prefix
# ncbigene       47782242  43796   76239  48324  25931         0        0     0
# hgnc              43796  43865       0      0      0         0        0     0
# mgi               76239      0  682164      0      0         0        0     0
# rgd               48324      0       0  61339      0         0        0     0
# cgnc              25931      0       0      0  25936         0        0     0
# wormbase              0      0       0      0      0         0        0     0
# flybase               0      0       0      0      0         0    17883     0
# sgd                   0      0       0      0      0         0        0  6600
# omim              18234  17153       0      0      0         0        0     0
# civic.gid           506      0       0      0      0         0        0     0
# umls                  0      0       0      0      0         0        0     0
# ncit                  0   5785       0      0      0         0        0     0
# wikidata         788061  43557       0      0      0         0        0     0
#
# target_prefix   omim  civic.gid  umls   ncit  wikidata
# source_prefix
# ncbigene       18234        506     0      0    788061
# hgnc           17153          0     0   5785     43557
# mgi                0          0     0      0         0
# rgd                0          0     0      0         0
# cgnc               0          0     0      0         0
# wormbase           0          0     0      0         0
# flybase            0          0     0      0         0
# sgd                0          0     0      0         0
# omim           26954          0     0      0     25906
# civic.gid          0        506     0      0       491
# umls               0          0     1      0         0
# ncit               0          0     0  12311         0
# wikidata       25906        491     0      0    797966
# Next, we summarize the processed mappings, which include inference, reasoning, and confidence filtering.
# target_prefix  ncbigene   hgnc     mgi    rgd   cgnc  wormbase  flybase   sgd  \
# source_prefix
# ncbigene       47782242  44191   76239  48324  25931         0        0     0
# hgnc              44191  43865       0      0      0         0        0     0
# mgi               76239      0  682164      0      0         0        0     0
# rgd               48324      0       0  61339      0         0        0     0
# cgnc              25931      0       0      0  25936         0        0     0
# wormbase              0      0       0      0      0         0        0     0
# flybase               0      0       0      0      0         0    17883     0
# sgd                   0      0       0      0      0         0        0  6600
# omim              18255  17534       0      0      0         0        0     0
# civic.gid           528    491       0      0      0         0        0     0
# umls                  0      0       0      0      0         0        0     0
# ncit               5761   5785       0      0      0         0        0     0
# wikidata         788874  43557       0      0      0         0        0     0
#
# target_prefix   omim  civic.gid  umls   ncit  wikidata
# source_prefix
# ncbigene       18255        528     0   5761    788874
# hgnc           17534        491     0   5785     43557
# mgi                0          0     0      0         0
# rgd                0          0     0      0         0
# cgnc               0          0     0      0         0
# wormbase           0          0     0      0         0
# flybase            0          0     0      0         0
# sgd                0          0     0      0         0
# omim           26954        491     0   5636     28144
# civic.gid        491        506     0    457       491
# umls               0          0     1      0         0
# ncit            5636        457     0  12311      5761
# wikidata       28144        491     0   5761    797966
# Below is an graph-based view on the processed mappings.
# ## Comparison
#
# The following comparison shows the absolute number of mappings added by processing/inference.
# Across the board, this process adds large numbers of mappings to most resources, especially
# ones that were previously only connected to a small number of other resources.
# target_prefix  ncbigene  hgnc  mgi  rgd  cgnc  wormbase  flybase  sgd  omim  \
# source_prefix
# ncbigene              0   395    0    0     0         0        0    0    21
# hgnc                395     0    0    0     0         0        0    0   381
# mgi                   0     0    0    0     0         0        0    0     0
# rgd                   0     0    0    0     0         0        0    0     0
# cgnc                  0     0    0    0     0         0        0    0     0
# wormbase              0     0    0    0     0         0        0    0     0
# flybase               0     0    0    0     0         0        0    0     0
# sgd                   0     0    0    0     0         0        0    0     0
# omim                 21   381    0    0     0         0        0    0     0
# civic.gid            22   491    0    0     0         0        0    0   491
# umls                  0     0    0    0     0         0        0    0     0
# ncit               5761     0    0    0     0         0        0    0  5636
# wikidata            813     0    0    0     0         0        0    0  2238
#
# target_prefix  civic.gid  umls  ncit  wikidata
# source_prefix
# ncbigene              22     0  5761       813
# hgnc                 491     0     0         0
# mgi                    0     0     0         0
# rgd                    0     0     0         0
# cgnc                   0     0     0         0
# wormbase               0     0     0         0
# flybase                0     0     0         0
# sgd                    0     0     0         0
# omim                 491     0  5636      2238
# civic.gid              0     0   457         0
# umls                   0     0     0         0
# ncit                 457     0     0      5761
# wikidata               0     0  5761         0
# Here's an alternative view on the number of mappings normalized to show percentage gain.
#
# Note:
#
# - `inf` means that there were no mappings before and now there are a non-zero number of mappings
# - `NaN` means there were no mappings before inference and continue to be no mappings after inference
# target_prefix  ncbigene  hgnc  mgi  rgd  cgnc  wormbase  flybase  sgd  omim  \
# source_prefix
# ncbigene            0.0   0.9  0.0  0.0   0.0       NaN      NaN  NaN   0.1
# hgnc                0.9   0.0  NaN  NaN   NaN       NaN      NaN  NaN   2.2
# mgi                 0.0   NaN  0.0  NaN   NaN       NaN      NaN  NaN   NaN
# rgd                 0.0   NaN  NaN  0.0   NaN       NaN      NaN  NaN   NaN
# cgnc                0.0   NaN  NaN  NaN   0.0       NaN      NaN  NaN   NaN
# wormbase            NaN   NaN  NaN  NaN   NaN       NaN      NaN  NaN   NaN
# flybase             NaN   NaN  NaN  NaN   NaN       NaN      0.0  NaN   NaN
# sgd                 NaN   NaN  NaN  NaN   NaN       NaN      NaN  0.0   NaN
# omim                0.1   2.2  NaN  NaN   NaN       NaN      NaN  NaN   0.0
# civic.gid           4.3   inf  NaN  NaN   NaN       NaN      NaN  NaN   inf
# umls                NaN   NaN  NaN  NaN   NaN       NaN      NaN  NaN   NaN
# ncit                inf   0.0  NaN  NaN   NaN       NaN      NaN  NaN   inf
# wikidata            0.1   0.0  NaN  NaN   NaN       NaN      NaN  NaN   8.6
#
# target_prefix  civic.gid  umls  ncit  wikidata
# source_prefix
# ncbigene             4.3   NaN   inf       0.1
# hgnc                 inf   NaN   0.0       0.0
# mgi                  NaN   NaN   NaN       NaN
# rgd                  NaN   NaN   NaN       NaN
# cgnc                 NaN   NaN   NaN       NaN
# wormbase             NaN   NaN   NaN       NaN
# flybase              NaN   NaN   NaN       NaN
# sgd                  NaN   NaN   NaN       NaN
# omim                 inf   NaN   inf       8.6
# civic.gid            0.0   NaN   inf       0.0
# umls                 NaN   0.0   NaN       NaN
# ncit                 inf   NaN   0.0       inf
# wikidata             0.0   NaN   inf       0.0
# ## Landscape Analysis
#
# Before, we looked at the overlaps between each resource. Now, we use that information jointly to
# estimate the number of terms in the landscape itself, and estimate how much of the landscape
# each resource covers.
# This estimates a total of 48,788,619 unique entities.
#
# - 859,853 (1.8%) have
#   at least one mapping.
# - 47,928,766 (98.2%)
#   are unique to a single resource.
# - 0 (0.0%)
#   appear in all 13 resources.
#
# This estimate is susceptible to several caveats:
#
# - Missing mappings inflates this measurement
# - Generic resources like MeSH contain irrelevant entities that can't be mapped
# Because there are 13, there are 8191 possible overlaps to consider.
# Therefore, a Venn diagram is not possible, so we
# we use an [UpSet plot](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4720993) (Lex *et al.*, 2014)
# as a high-dimensional Venn diagram.
# We now aggregate the mappings together to estimate the number of unique entities and number
# that appear in each group of resources.
# \
#         The landscape of 13 resources has 49,457,767 total terms.
#         After merging redundant nodes based on mappings, inference, and reasoning, there
#         are 48,788,619 unique concepts. Using the reduction formula
#         $\frac{\text{total terms} - \text{reduced terms}}{\text{total terms}}$,
#         this is a 1.4% reduction.
# This is only an estimate and is susceptible to a few things:
#
# 1. It can be artificially high because there are entities that _should_ be mapped, but are not
# 2. It can be artificially low because there are entities that are incorrectly mapped, e.g., as
#    a result of inference. The frontend curation interface can help identify and remove these
# 3. It can be artificially low because for some vocabularies like SNOMED-CT, it's not possible
#    to load a terms list, and therefore it's not possible to account for terms that aren't mapped.
#    Therefore, we make a lower bound estimate based on the terms that appear in mappings
# 4. It can be artificially high if a vocabulary is used that covers many domains and is not properly
#    subset'd. For example, EFO covers many different domains, so when doing disease landscape
#    analysis, it should be subset to only terms in the disease hierarchy (i.e., appearing under
#    ``efo:0000408``).
# 5. It can be affected by terminology issues, such as the confusion between Orphanet and ORDO
# 6. It can be affected by the existence of many-to-many mappings, which are filtered out during
#    processing, which makes the estimate artificially high since some subset of those entities
#    could be mapped, but it's not clear which should.
