# %%
from semra.landscape.diseases import CONFIGURATION
from semra.landscape.utils import notebook
# Out:
# /Users/cthoyt/.virtualenvs/indra/lib/python3.11/site-packages/pydantic/_internal/_config.py:322: UserWarning: Valid config keys have changed in V2:
# * 'underscore_attrs_are_private' has been removed
#   warnings.warn(message, UserWarning)

# %%
_ = notebook(CONFIGURATION, output_directory=".")
# Out:
# ## Summarize the Resources
#
# We summarize the resources used in the landscape analysis, including their [Bioregistry](https://bioregistry.io)
# prefix, license, current version, and number of terms (i.e., named concepts) they contain.
# 1 resources were not available through
# [PyOBO](https://github.com/biopragmatics/pyobo). Therefore, we estimate the number
# of terms in that resource based on the ones appearing in mappings. Note that these
# are typically an underestimate.
#                                                             name  \
# prefix
# doid                                      Human Disease Ontology
# mondo                                     Mondo Disease Ontology
# efo                                 Experimental Factor Ontology
# mesh                                    Medical Subject Headings
# ncit                                               NCI Thesaurus
# orphanet                                                Orphanet
# orphanet.ordo                     Orphanet Rare Disease Ontology
# umls           Unified Medical Language System Concept Unique...
# omim                         Online Mendelian Inheritance in Man
# omim.ps                                   OMIM Phenotypic Series
# gard                Genetic and Rare Diseases Information Center
# icd10          International Classification of Diseases, 10th...
# icd10cm        International Classification of Diseases, 10th...
# icd10pcs       International Classification of Diseases, 10th...
# icd11          International Classification of Diseases, 11th...
# icd9           International Classification of Diseases, 9th ...
# icd9cm         International Classification of Diseases, 9th ...
# icdo           International Classification of Diseases for O...
#
#                                                          license  \
# prefix
# doid                                                     CC0-1.0
# mondo                                                  CC-BY-4.0
# efo                                                   Apache-2.0
# mesh                                                     CC0-1.0
# ncit                                                   CC-BY-4.0
# orphanet                                               CC-BY-4.0
# orphanet.ordo                                          CC-BY-4.0
# umls           https://www.nlm.nih.gov/research/umls/knowledg...
# omim                         https://www.omim.org/help/agreement
# omim.ps                      https://www.omim.org/help/agreement
# gard                                                        None
# icd10          https://cdn.who.int/media/docs/default-source/...
# icd10cm                                                     None
# icd10pcs                                                    None
# icd11                                           CC-BY-ND-3.0-IGO
# icd9                                                        None
# icd9cm                                                      None
# icdo                                                        None
#
#                      version   terms    status
# prefix
# doid              2024-03-28   11537      full
# mondo             2024-04-02   24201      full
# efo                   3.64.0    2080    subset
# mesh                    2024    3125    subset
# ncit                  24.02d   20095    subset
# orphanet                None   15348      full
# orphanet.ordo            4.4   14473  observed
# umls                  2023AB  178734    subset
# omim           April 9, 2024   20268  observed
# omim.ps        April 9, 2024     576      full
# gard                    None   12292  observed
# icd10                   2019    2345      full
# icd10cm                 None   21556  observed
# icd10pcs                None       0  observed
# icd11                2024-01   69477      full
# icd9                    None    3984  observed
# icd9cm                  None    9236  observed
# icdo                    None     800  observed
# There are a total of 410,127 terms across the 18 resources.
# ## Summarize the Mappings
#
# In order to summarize the mappings, we're going to load them, index them, and count
# the number of mappings between each pair of resources. The self-mapping column is
# the count of terms in the resource. We'll do this to the raw mappings first, then
# to the processed mappings, then compare them.
# Indexing mappings:   0%|          | 0.00/412k [00:00<?, ?mapping/s]
# Indexing mappings:   0%|          | 0.00/708k [00:00<?, ?mapping/s]
# First, we summarize the raw mappings, i.e., the mappings that are directly available from the sources
# target_prefix   doid  mondo   efo  mesh   ncit  orphanet  orphanet.ordo  \
# source_prefix
# doid           11537  11149  1216   628   4613         0           2113
# mondo          11149  24201  1626   855   6974         0           9529
# efo             1216   1626  2080   326   1116         0             36
# mesh             628    855   326  3125     27         0              0
# ncit            4613   6974  1116    27  20095         0              0
# orphanet           0      0     0     0      0     15348              0
# orphanet.ordo   2113   9529    36     0      0         0          14473
# umls            6732  13894  1069  2112  18777      8356           7854
# omim            5924   9871   321     0      0         0          11146
# omim.ps            0    580    24     0      0         0              0
# gard            2110  11838   304     0      0         0              0
# icd10              1     15   502     0      0         0           7623
# icd10cm         3528   1636   285     0      0         0              0
# icd10pcs           0      0     0     0      0         0              0
# icd11              1      0     0     0      0         0           5484
# icd9               0   4342  1167     0      0         0              0
# icd9cm          2237      2     5     0      0         0              0
# icdo             470    732    72     0      0         0              0
#
# target_prefix    umls   omim  omim.ps   gard  icd10  icd10cm  icd10pcs  icd11  \
# source_prefix
# doid             6732   5924        0   2110      1     3528         0      1
# mondo           13894   9871      580  11838     15     1636         0      0
# efo              1069    321       24    304    502      285         0      0
# mesh             2112      0        0      0      0        0         0      0
# ncit            18777      0        0      0      0        0         0      0
# orphanet         8356      0        0      0      0        0         0      0
# orphanet.ordo    7854  11146        0      0   7623        0         0   5484
# umls           178734  18049        0      0   5762    24877         0      0
# omim            18049  20268        0      0      0        0         0      0
# omim.ps             0      0      576      0      0        0         0      0
# gard                0      0        0  12292      0        0         0      0
# icd10            5762      0        0      0   2345        0         0      0
# icd10cm         24877      0        0      0      0    21556         0      0
# icd10pcs            0      0        0      0      0        0         0      0
# icd11               0      0        0      0      0        0         0  69477
# icd9                0      0        0      0      0        0         0      0
# icd9cm           9109      0        0      0      0        0         0      0
# icdo                0      0        0      0      0        0         0      0
#
# target_prefix  icd9  icd9cm  icdo
# source_prefix
# doid              0    2237   470
# mondo          4342       2   732
# efo            1167       5    72
# mesh              0       0     0
# ncit              0       0     0
# orphanet          0       0     0
# orphanet.ordo     0       0     0
# umls              0    9109     0
# omim              0       0     0
# omim.ps           0       0     0
# gard              0       0     0
# icd10             0       0     0
# icd10cm           0       0     0
# icd10pcs          0       0     0
# icd11             0       0     0
# icd9           3984       0     0
# icd9cm            0    9236     0
# icdo              0       0   800
# Next, we summarize the processed mappings, which include inference, reasoning, and confidence filtering.
# target_prefix   doid  mondo   efo  mesh   ncit  orphanet  orphanet.ordo  \
# source_prefix
# doid           11537  11316  1253   726   5041       358           2426
# mondo          11316  24201  1691   878   7203      2048           9559
# efo             1253   1691  2080   363   1222       140            184
# mesh             726    878   363  3125    370       112            120
# ncit            5041   7203  1222   370  20095       411            416
# orphanet         358   2048   140   112    411     15348           2159
# orphanet.ordo   2426   9559   184   120    416      2159          14473
# umls            7639  16239  1538  2201  18988      8356           8068
# omim            5938   9872   327    12    120       136          11166
# omim.ps           37    580    26     2     16        23             26
# gard            2110  11839   304     0      1         0              0
# icd10              7     15   503     1      6         0           7623
# icd10cm         3583   1656   309   181    439       140            151
# icd10pcs           0      0     0     0      0         0              0
# icd11              1      0     0     0      0         0           5484
# icd9               0   4342  1167     0      0         0              0
# icd9cm          2237      2     5     0      0         0              0
# icdo             470    732    72     0      0         0              0
#
# target_prefix    umls   omim  omim.ps   gard  icd10  icd10cm  icd10pcs  icd11  \
# source_prefix
# doid             7639   5938       37   2110      7     3583         0      1
# mondo           16239   9872      580  11839     15     1656         0      0
# efo              1538    327       26    304    503      309         0      0
# mesh             2201     12        2      0      1      181         0      0
# ncit            18988    120       16      1      6      439         0      0
# orphanet         8356    136       23      0      0      140         0      0
# orphanet.ordo    8068  11166       26      0   7623      151         0   5484
# umls           178734  18057       33      1   5768    24995         0      0
# omim            18057  20268        0      1      0       38         0      0
# omim.ps            33      0      576      0      0        5         0      0
# gard                1      1        0  12292      0        0         0      0
# icd10            5768      0        0      0   2345        7         0      0
# icd10cm         24995     38        5      0      7    21556         0      0
# icd10pcs            0      0        0      0      0        0         0      0
# icd11               0      0        0      0      0        0         0  69477
# icd9                0      0        0      0      0        0         0      0
# icd9cm           9109      0        0      0      0        0         0      0
# icdo                0      0        0      0      0        0         0      0
#
# target_prefix  icd9  icd9cm  icdo
# source_prefix
# doid              0    2237   470
# mondo          4342       2   732
# efo            1167       5    72
# mesh              0       0     0
# ncit              0       0     0
# orphanet          0       0     0
# orphanet.ordo     0       0     0
# umls              0    9109     0
# omim              0       0     0
# omim.ps           0       0     0
# gard              0       0     0
# icd10             0       0     0
# icd10cm           0       0     0
# icd10pcs          0       0     0
# icd11             0       0     0
# icd9           3984       0     0
# icd9cm            0    9236     0
# icdo              0       0   800
# Below is an graph-based view on the processed mappings.
# ## Comparison
#
# The following comparison shows the absolute number of mappings added by processing/inference.
# Across the board, this process adds large numbers of mappings to most resources, especially
# ones that were previously only connected to a small number of other resources.
# target_prefix  doid  mondo  efo  mesh  ncit  orphanet  orphanet.ordo  umls  \
# source_prefix
# doid              0    167   37    98   428       358            313   907
# mondo           167      0   65    23   229      2048             30  2345
# efo              37     65    0    37   106       140            148   469
# mesh             98     23   37     0   343       112            120    89
# ncit            428    229  106   343     0       411            416   211
# orphanet        358   2048  140   112   411         0           2159     0
# orphanet.ordo   313     30  148   120   416      2159              0   214
# umls            907   2345  469    89   211         0            214     0
# omim             14      1    6    12   120       136             20     8
# omim.ps          37      0    2     2    16        23             26    33
# gard              0      1    0     0     1         0              0     1
# icd10             6      0    1     1     6         0              0     6
# icd10cm          55     20   24   181   439       140            151   118
# icd10pcs          0      0    0     0     0         0              0     0
# icd11             0      0    0     0     0         0              0     0
# icd9              0      0    0     0     0         0              0     0
# icd9cm            0      0    0     0     0         0              0     0
# icdo              0      0    0     0     0         0              0     0
#
# target_prefix  omim  omim.ps  gard  icd10  icd10cm  icd10pcs  icd11  icd9  \
# source_prefix
# doid             14       37     0      6       55         0      0     0
# mondo             1        0     1      0       20         0      0     0
# efo               6        2     0      1       24         0      0     0
# mesh             12        2     0      1      181         0      0     0
# ncit            120       16     1      6      439         0      0     0
# orphanet        136       23     0      0      140         0      0     0
# orphanet.ordo    20       26     0      0      151         0      0     0
# umls              8       33     1      6      118         0      0     0
# omim              0        0     1      0       38         0      0     0
# omim.ps           0        0     0      0        5         0      0     0
# gard              1        0     0      0        0         0      0     0
# icd10             0        0     0      0        7         0      0     0
# icd10cm          38        5     0      7        0         0      0     0
# icd10pcs          0        0     0      0        0         0      0     0
# icd11             0        0     0      0        0         0      0     0
# icd9              0        0     0      0        0         0      0     0
# icd9cm            0        0     0      0        0         0      0     0
# icdo              0        0     0      0        0         0      0     0
#
# target_prefix  icd9cm  icdo
# source_prefix
# doid                0     0
# mondo               0     0
# efo                 0     0
# mesh                0     0
# ncit                0     0
# orphanet            0     0
# orphanet.ordo       0     0
# umls                0     0
# omim                0     0
# omim.ps             0     0
# gard                0     0
# icd10               0     0
# icd10cm             0     0
# icd10pcs            0     0
# icd11               0     0
# icd9                0     0
# icd9cm              0     0
# icdo                0     0
# Here's an alternative view on the number of mappings normalized to show percentage gain.
#
# Note:
#
# - `inf` means that there were no mappings before and now there are a non-zero number of mappings
# - `NaN` means there were no mappings before inference and continue to be no mappings after inference
# target_prefix   doid  mondo    efo    mesh    ncit  orphanet  orphanet.ordo  \
# source_prefix
# doid             0.0    1.5    3.0    15.6     9.3       inf           14.8
# mondo            1.5    0.0    4.0     2.7     3.3       inf            0.3
# efo              3.0    4.0    0.0    11.3     9.5       inf          411.1
# mesh            15.6    2.7   11.3     0.0  1270.4       inf            inf
# ncit             9.3    3.3    9.5  1270.4     0.0       inf            inf
# orphanet         inf    inf    inf     inf     inf       0.0            inf
# orphanet.ordo   14.8    0.3  411.1     inf     inf       inf            0.0
# umls            13.5   16.9   43.9     4.2     1.1       0.0            2.7
# omim             0.2    0.0    1.9     inf     inf       inf            0.2
# omim.ps          inf    0.0    8.3     inf     inf       inf            inf
# gard             0.0    0.0    0.0     NaN     inf       NaN            NaN
# icd10          600.0    0.0    0.2     inf     inf       NaN            0.0
# icd10cm          1.6    1.2    8.4     inf     inf       inf            inf
# icd10pcs         NaN    NaN    NaN     NaN     NaN       NaN            NaN
# icd11            0.0    NaN    NaN     NaN     NaN       NaN            0.0
# icd9             NaN    0.0    0.0     NaN     NaN       NaN            NaN
# icd9cm           0.0    0.0    0.0     NaN     NaN       NaN            NaN
# icdo             0.0    0.0    0.0     NaN     NaN       NaN            NaN
#
# target_prefix  umls  omim  omim.ps  gard  icd10  icd10cm  icd10pcs  icd11  \
# source_prefix
# doid           13.5   0.2      inf   0.0  600.0      1.6       NaN    0.0
# mondo          16.9   0.0      0.0   0.0    0.0      1.2       NaN    NaN
# efo            43.9   1.9      8.3   0.0    0.2      8.4       NaN    NaN
# mesh            4.2   inf      inf   NaN    inf      inf       NaN    NaN
# ncit            1.1   inf      inf   inf    inf      inf       NaN    NaN
# orphanet        0.0   inf      inf   NaN    NaN      inf       NaN    NaN
# orphanet.ordo   2.7   0.2      inf   NaN    0.0      inf       NaN    0.0
# umls            0.0   0.0      inf   inf    0.1      0.5       NaN    NaN
# omim            0.0   0.0      NaN   inf    NaN      inf       NaN    NaN
# omim.ps         inf   NaN      0.0   NaN    NaN      inf       NaN    NaN
# gard            inf   inf      NaN   0.0    NaN      NaN       NaN    NaN
# icd10           0.1   NaN      NaN   NaN    0.0      inf       NaN    NaN
# icd10cm         0.5   inf      inf   NaN    inf      0.0       NaN    NaN
# icd10pcs        NaN   NaN      NaN   NaN    NaN      NaN       NaN    NaN
# icd11           NaN   NaN      NaN   NaN    NaN      NaN       NaN    0.0
# icd9            NaN   NaN      NaN   NaN    NaN      NaN       NaN    NaN
# icd9cm          0.0   NaN      NaN   NaN    NaN      NaN       NaN    NaN
# icdo            NaN   NaN      NaN   NaN    NaN      NaN       NaN    NaN
#
# target_prefix  icd9  icd9cm  icdo
# source_prefix
# doid            NaN     0.0   0.0
# mondo           0.0     0.0   0.0
# efo             0.0     0.0   0.0
# mesh            NaN     NaN   NaN
# ncit            NaN     NaN   NaN
# orphanet        NaN     NaN   NaN
# orphanet.ordo   NaN     NaN   NaN
# umls            NaN     0.0   NaN
# omim            NaN     NaN   NaN
# omim.ps         NaN     NaN   NaN
# gard            NaN     NaN   NaN
# icd10           NaN     NaN   NaN
# icd10cm         NaN     NaN   NaN
# icd10pcs        NaN     NaN   NaN
# icd11           NaN     NaN   NaN
# icd9            0.0     NaN   NaN
# icd9cm          NaN     0.0   NaN
# icdo            NaN     NaN   0.0
# ## Landscape Analysis
#
# Before, we looked at the overlaps between each resource. Now, we use that information jointly to
# estimate the number of terms in the landscape itself, and estimate how much of the landscape
# each resource covers.
# This estimates a total of 243,290 unique entities.
#
# - 44,695 (18.4%) have
#   at least one mapping.
# - 198,595 (81.6%)
#   are unique to a single resource.
# - 0 (0.0%)
#   appear in all 18 resources.
#
# This estimate is susceptible to several caveats:
#
# - Missing mappings inflates this measurement
# - Generic resources like MeSH contain irrelevant entities that can't be mapped
# Because there are 18, there are 262143 possible overlaps to consider.
# Therefore, a Venn diagram is not possible, so we
# we use an [UpSet plot](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4720993) (Lex *et al.*, 2014)
# as a high-dimensional Venn diagram.
# We now aggregate the mappings together to estimate the number of unique entities and number
# that appear in each group of resources.
# \
#         The landscape of 18 resources has 410,127 total terms.
#         After merging redundant nodes based on mappings, inference, and reasoning, there
#         are 243,290 unique concepts. Using the reduction formula
#         $\frac{\text{total terms} - \text{reduced terms}}{\text{total terms}}$,
#         this is a 40.7% reduction.
# This is only an estimate and is susceptible to a few things:
#
# 1. It can be artificially high because there are entities that _should_ be mapped, but are not
# 2. It can be artificially low because there are entities that are incorrectly mapped, e.g., as
#    a result of inference. The frontend curation interface can help identify and remove these
# 3. It can be artificially low because for some vocabularies like SNOMED-CT, it's not possible
#    to load a terms list, and therefore it's not possible to account for terms that aren't mapped.
#    Therefore, we make a lower bound estimate based on the terms that appear in mappings
# 4. It can be artificially high if a vocabulary is used that covers many domains and is not properly
#    subset'd. For example, EFO covers many different domains, so when doing disease landscape
#    analysis, it should be subset to only terms in the disease hierarchy (i.e., appearing under
#    ``efo:0000408``).
# 5. It can be affected by terminology issues, such as the confusion between Orphanet and ORDO
# 6. It can be affected by the existence of many-to-many mappings, which are filtered out during
#    processing, which makes the estimate artificially high since some subset of those entities
#    could be mapped, but it's not clear which should.
