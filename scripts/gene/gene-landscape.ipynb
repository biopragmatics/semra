# %%
from gene import CONFIGURATION

from semra.analysis.landscape import notebook
# Out:
# /Users/cthoyt/.virtualenvs/indra/lib/python3.11/site-packages/pydantic/_internal/_config.py:322: UserWarning: Valid config keys have changed in V2:
# * 'underscore_attrs_are_private' has been removed
#   warnings.warn(message, UserWarning)

# %%
notebook(CONFIGURATION, output_directory=".")
# Out:
# ## Summarize the Resources
#
# We summarize the resources used in the landscape analysis, including their [Bioregistry](https://bioregistry.io)
# prefix, license, current version, and number of terms (i.e., named concepts) they contain.
# 3 resources were not available through
# [PyOBO](https://github.com/biopragmatics/pyobo) and therefore list zero terms.
#                                                         name  \
# prefix
# ncbigene                                         Entrez Gene
# hgnc                        HUGO Gene Nomenclature Committee
# mgi                                 Mouse Genome Informatics
# rgd                                      Rat Genome Database
# cgnc                    Chicken Gene Nomenclature Consortium
# wormbase                                       Wormbase Gene
# flybase                                         FlyBase Gene
# sgd                            Saccharomyces Genome Database
# omim                     Online Mendelian Inheritance in Man
# civic.gid                                         CIViC gene
# umls       Unified Medical Language System Concept Unique...
# ncit                                           NCI Thesaurus
# wikidata                                            Wikidata
#
#                                                      license        version  \
# prefix
# ncbigene                                                None          daily
# hgnc                                                 CC0-1.0     2024-03-01
# mgi                                                CC-BY-4.0           6.23
# rgd                                                CC-BY-4.0     2024-03-22
# cgnc                                                    None           None
# wormbase                                                None           None
# flybase                                                 None        2024_01
# sgd                                                     None        R64-3-1
# omim                     https://www.omim.org/help/agreement  April 2, 2024
# civic.gid                                            CC0-1.0    01-Apr-2024
# umls       https://www.nlm.nih.gov/research/umls/knowledg...         2023AB
# ncit                                               CC-BY-4.0         24.02d
# wikidata                                             CC0-1.0           None
#
#               terms
# prefix
# ncbigene   47782242
# hgnc          43865
# mgi          682164
# rgd           61339
# cgnc          25936
# wormbase          0
# flybase       17883
# sgd            6600
# omim              0
# civic.gid       506
# umls        3185657
# ncit         181982
# wikidata          0
# ## Summarize the Mappings
#
# In order to summarize the mappings, we're going to load them, index them, and count
# the number of mappings between each pair of resources. The self-mapping column is
# the count of terms in the resource. We'll do this to the raw mappings first, then
# to the processed mappings, then compare them.
# Indexing mappings:   0%|          | 0.00/1.61M [00:00<?, ?mapping/s]
# Indexing mappings:   0%|          | 0.00/3.61M [00:00<?, ?mapping/s]
# First, we summarize the raw mappings, i.e., the mappings that are directly available from the sources
# target_prefix  ncbigene   hgnc     mgi    rgd   cgnc  flybase   sgd   omim  \
# source_prefix
# ncbigene       47782242  43796   76239  48324  25931        0     0  18232
# hgnc              43796  43865       0      0      0        0     0  17153
# mgi               76239      0  682164      0      0        0     0      0
# rgd               48324      0       0  61339      0        0     0      0
# cgnc              25931      0       0      0  25936        0     0      0
# flybase               0      0       0      0      0    17883     0      0
# sgd                   0      0       0      0      0        0  6600      0
# omim              18232  17153       0      0      0        0     0      0
# civic.gid           506      0       0      0      0        0     0      0
# umls                  0      0       0      0      0        0     0      0
# ncit                  0   5893       0      0      0        0     0      0
# wikidata         788062  43557       0      0      0        0     0  25906
#
# target_prefix  civic.gid     umls    ncit  wikidata
# source_prefix
# ncbigene             506        0       0    788062
# hgnc                   0        0    5893     43557
# mgi                    0        0       0         0
# rgd                    0        0       0         0
# cgnc                   0        0       0         0
# flybase                0        0       0         0
# sgd                    0        0       0         0
# omim                   0        0       0     25906
# civic.gid            506        0       0       491
# umls                   0  3185657       0         0
# ncit                   0        0  181982         0
# wikidata             491        0       0         0
# Next, we summarize the processed mappings, which include inference, reasoning, and confidence filtering.
# target_prefix  ncbigene   hgnc     mgi    rgd   cgnc  flybase   sgd   omim  \
# source_prefix
# ncbigene       47782242  44190   76239  48324  25931        0     0  18253
# hgnc              44190  43865       0      0      0        0     0  17533
# mgi               76239      0  682164      0      0        0     0      0
# rgd               48324      0       0  61339      0        0     0      0
# cgnc              25931      0       0      0  25936        0     0      0
# flybase               0      0       0      0      0    17883     0      0
# sgd                   0      0       0      0      0        0  6600      0
# omim              18253  17533       0      0      0        0     0      0
# civic.gid           528    491       0      0      0        0     0    491
# umls                  0      0       0      0      0        0     0      0
# ncit               5877   5893       0      0      0        0     0   5757
# wikidata         788875  43557       0      0      0        0     0  28143
#
# target_prefix  civic.gid     umls    ncit  wikidata
# source_prefix
# ncbigene             528        0    5877    788875
# hgnc                 491        0    5893     43557
# mgi                    0        0       0         0
# rgd                    0        0       0         0
# cgnc                   0        0       0         0
# flybase                0        0       0         0
# sgd                    0        0       0         0
# omim                 491        0    5757     28143
# civic.gid            506        0     457       491
# umls                   0  3185657       0         0
# ncit                 457        0  181982      5880
# wikidata             491        0    5880         0
# Below is an graph-based view on the processed mappings.
# ## Comparison
#
# The following comparison shows the absolute number of mappings added by processing/inference.
# Across the board, this process adds large numbers of mappings to most resources, especially
# ones that were previously only connected to a small number of other resources.
# target_prefix  ncbigene  hgnc  mgi  rgd  cgnc  flybase  sgd  omim  civic.gid  \
# source_prefix
# ncbigene              0   394    0    0     0        0    0    21         22
# hgnc                394     0    0    0     0        0    0   380        491
# mgi                   0     0    0    0     0        0    0     0          0
# rgd                   0     0    0    0     0        0    0     0          0
# cgnc                  0     0    0    0     0        0    0     0          0
# flybase               0     0    0    0     0        0    0     0          0
# sgd                   0     0    0    0     0        0    0     0          0
# omim                 21   380    0    0     0        0    0     0        491
# civic.gid            22   491    0    0     0        0    0   491          0
# umls                  0     0    0    0     0        0    0     0          0
# ncit               5877     0    0    0     0        0    0  5757        457
# wikidata            813     0    0    0     0        0    0  2237          0
#
# target_prefix  umls  ncit  wikidata
# source_prefix
# ncbigene          0  5877       813
# hgnc              0     0         0
# mgi               0     0         0
# rgd               0     0         0
# cgnc              0     0         0
# flybase           0     0         0
# sgd               0     0         0
# omim              0  5757      2237
# civic.gid         0   457         0
# umls              0     0         0
# ncit              0     0      5880
# wikidata          0  5880         0
# Here's an alternative view on the number of mappings normalized to show percentage gain.
#
# Note:
#
# - `inf` means that there were no mappings before and now there are a non-zero number of mappings
# - `NaN` means there were no mappings before inference and continue to be no mappings after inference
# target_prefix  ncbigene  hgnc  mgi  rgd  cgnc  flybase  sgd  omim  civic.gid  \
# source_prefix
# ncbigene            0.0   0.9  0.0  0.0   0.0      NaN  NaN   0.1        4.3
# hgnc                0.9   0.0  NaN  NaN   NaN      NaN  NaN   2.2        inf
# mgi                 0.0   NaN  0.0  NaN   NaN      NaN  NaN   NaN        NaN
# rgd                 0.0   NaN  NaN  0.0   NaN      NaN  NaN   NaN        NaN
# cgnc                0.0   NaN  NaN  NaN   0.0      NaN  NaN   NaN        NaN
# flybase             NaN   NaN  NaN  NaN   NaN      0.0  NaN   NaN        NaN
# sgd                 NaN   NaN  NaN  NaN   NaN      NaN  0.0   NaN        NaN
# omim                0.1   2.2  NaN  NaN   NaN      NaN  NaN   NaN        inf
# civic.gid           4.3   inf  NaN  NaN   NaN      NaN  NaN   inf        0.0
# umls                NaN   NaN  NaN  NaN   NaN      NaN  NaN   NaN        NaN
# ncit                inf   0.0  NaN  NaN   NaN      NaN  NaN   inf        inf
# wikidata            0.1   0.0  NaN  NaN   NaN      NaN  NaN   8.6        0.0
#
# target_prefix  umls  ncit  wikidata
# source_prefix
# ncbigene        NaN   inf       0.1
# hgnc            NaN   0.0       0.0
# mgi             NaN   NaN       NaN
# rgd             NaN   NaN       NaN
# cgnc            NaN   NaN       NaN
# flybase         NaN   NaN       NaN
# sgd             NaN   NaN       NaN
# omim            NaN   inf       8.6
# civic.gid       NaN   inf       0.0
# umls            0.0   NaN       NaN
# ncit            NaN   0.0       inf
# wikidata        NaN   inf       NaN
# ## Landscape Analysis
#
# Before, we looked at the overlaps between each resource. Now, we use that information jointly to
# estimate the number of terms in the landscape itself, and estimate how much of the landscape
# each resource covers.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 notebook(CONFIGURATION, output_directory=".")
#
# File ~/dev/semra/src/semra/analysis/landscape.py:136, in notebook(configuration, subsets, output_directory, matplotlib_formats)
#     125 _markdown(
#     126     """\
#     127     ## Landscape Analysis
#    (...)
#     132 """
#     133 )
#     134 # note we're using the sliced counts dataframe index instead of the
#     135 # original priority since we threw a couple prefixes away along the way
# --> 136 landscape_results = landscape_analysis(
#     137     overlap_results.mappings, terms=terms, priority=overlap_results.counts_df.index
#     138 )
#     140 _markdown(landscape_results.get_description_markdown())
#     142 n_prefixes = len(overlap_results.counts_df.index)
#
# File ~/dev/semra/src/semra/analysis/landscape.py:468, in landscape_analysis(mappings, terms, priority)
#     465         continue
#     467     prefix_terms_set = set(prefix_terms)
# --> 468     mapped_terms: t.Set[str] = entities[prefix]
#     469     counter[frozenset([prefix])] = unique_to_single[prefix] = len(prefix_terms_set - mapped_terms)
#     471 #: A count of the number of entities that have no mappings.
#     472 #: This is calculated based on the set difference between entities
#     473 #: appearing in mappings and the preloaded terms lists
#
# KeyError: 'flybase'
