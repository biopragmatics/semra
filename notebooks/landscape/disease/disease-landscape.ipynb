# %%
from semra.landscape.diseases import CONFIGURATION
from semra.landscape.utils import notebook

# %%
_ = notebook(CONFIGURATION, output_directory=".")
# Out:
# ## Summarize the Resources
#
# We summarize the resources used in the landscape analysis, including their
# [Bioregistry](https://bioregistry.io) prefix, license, current version, and
# number of terms (i.e., named concepts) they contain.
# 3 resources were not available through
# [PyOBO](https://github.com/biopragmatics/pyobo). Therefore, we estimate the number
# of terms in that resource based on the ones appearing in mappings. Note that these
# are typically an underestimate.
#                                                             name  \
# prefix
# doid                                      Human Disease Ontology
# mondo                                     Mondo Disease Ontology
# efo                                 Experimental Factor Ontology
# mesh                                    Medical Subject Headings
# ncit                                               NCI Thesaurus
# orphanet                                                Orphanet
# orphanet.ordo                     Orphanet Rare Disease Ontology
# umls           Unified Medical Language System Concept Unique...
# omim                         Online Mendelian Inheritance in Man
# omim.ps                                   OMIM Phenotypic Series
# gard                Genetic and Rare Diseases Information Center
# icd10          International Classification of Diseases, 10th...
# icd10cm        International Classification of Diseases, 10th...
# icd10pcs       International Classification of Diseases, 10th...
# icd11          International Classification of Diseases, 11th...
# icd11.code                                          ICD 11 Codes
# icd9           International Classification of Diseases, 9th ...
# icd9cm         International Classification of Diseases, 9th ...
# icdo           International Classification of Diseases for O...
#
#                                                          license     version  \
# prefix
# doid                                                     CC0-1.0  2025-03-03
# mondo                                                  CC-BY-4.0  2025-03-04
# efo                                                   Apache-2.0      3.76.0
# mesh                                                     CC0-1.0        2025
# ncit                                                   CC-BY-4.0      25.03c
# orphanet                                               CC-BY-4.0        None
# orphanet.ordo                                          CC-BY-4.0         4.6
# umls           https://www.nlm.nih.gov/research/umls/knowledg...      2024AB
# omim                         https://www.omim.org/help/agreement  2025-03-24
# omim.ps                      https://www.omim.org/help/agreement  2025-03-24
# gard                                                        None        None
# icd10          https://cdn.who.int/media/docs/default-source/...        2019
# icd10cm                                                     None        None
# icd10pcs                                                    None        None
# icd11                                           CC-BY-ND-3.0-IGO     2025-01
# icd11.code     http://www.who.int/about/licensing/copyright_f...        None
# icd9                                                        None        None
# icd9cm                                                      None        None
# icdo                                                        None        None
#
#                 terms    status
# prefix
# doid            14220      full
# mondo           29826      full
# efo              2121    subset
# mesh             3178    subset
# ncit            20522    subset
# orphanet            0  observed
# orphanet.ordo   15507      full
# umls           187376    subset
# omim            14452  observed
# omim.ps           588      full
# gard             6132      full
# icd10            2345      full
# icd10cm          2830  observed
# icd10pcs            0  observed
# icd11           71175      full
# icd11.code          0  observed
# icd9             3955  observed
# icd9cm           2226  observed
# icdo              797  observed
# There are a total of 377,250 terms across the 19 resources.
# ## Summarize the Mappings
#
# In order to summarize the mappings, we're going to load them, index them, and count
# the number of mappings between each pair of resources. The self-mapping column is
# the count of terms in the resource. We'll do this to the raw mappings first, then
# to the processed mappings, then compare them.
# First, we summarize the raw mappings, i.e., the mappings that are directly available from the sources
# target_prefix   doid  mondo   efo  mesh   ncit  orphanet  orphanet.ordo  \
# source_prefix
# doid           14220  11638  1243   628   4635         0           2199
# mondo          11638  29826  1447   863   7149         0           9585
# efo             1243   1447  2121   400   1104         0            276
# mesh             628    863   400  3178     27         0              1
# ncit            4635   7149  1104    27  20522         0             37
# orphanet           0      0     0     0      0         0              0
# mondo           20807   9993      591  10733     18     1714         0   4139
# efo              1715    324       26    290    526      324         0    410
# mesh              812     20        2      0      3      221         0      0
# ncit             5175    285       64      9     10      570         0      0
# orphanet            0      0        0      0      0        0         0      0
# orphanet.ordo    8724  11449       98     47   7850      214         0      1
# umls           187376   2820      139     11     17      979         0      0
# omim             2820  14452        3      5      1       58         0      0
# omim.ps           139      3      588      3      0       16         0      0
# gard               11      5        3   6132      0        2         0      0
# icd10              17      1        0      0   2345       10         0      0
# icd10cm           979     58       16      2     10     2830         0      0
# icd10pcs            0      0        0      0      0        0         0      0
# icd11               0      0        0      0      0        0         0  71175
# icd11.code          0      0        0      0      0        0         0      0
# icd9                0      0        0      0      0        0         0      0
# icd9cm              1      0        1      2      0        2         0      0
# icdo                0      0        0      0      0        0         0      0
#
# target_prefix  icd11.code  icd9  icd9cm  icdo
# source_prefix
# doid                    0    11    2225   488
# mondo                   0  4417       5   725
# efo                     0  1194       6    62
# mesh                    0     0       0     0
# ncit                    0     0       2     0
# orphanet                0     0       0     0
# orphanet.ordo           0     5       2     1
# umls                    0     0       1     0
# omim                    0     0       0     0
# omim.ps                 0     0       1     0
# gard                    0     0       2     0
# icd10                   0     0       0     0
# icd10cm                 0     0       2     0
# icd10pcs                0     0       0     0
# icd11                   0     0       0     0
# icd11.code              0     0       0     0
# icd9                    0  3955       0     0
# icd9cm                  0     0    2226     0
# icdo                    0     0       0   797
# Below is an graph-based view on the processed mappings.
# ## Comparison
#
# The following comparison shows the absolute number of mappings added by processing/inference.
# Across the board, this process adds large numbers of mappings to most resources, especially
# ones that were previously only connected to a small number of other resources.
# target_prefix  doid  mondo  efo  mesh  ncit  orphanet  orphanet.ordo  umls  \
# source_prefix
# doid              0    203   62    91   553         0            531  1658
# mondo           203      0  248    56   162         0            175  1530
# efo              62    248    0    25   116         0             54   377
# mesh             91     56   25     0   419         0            150   811
# ncit            553    162  116   419     0         0            837  5175
# orphanet          0      0    0     0     0         0              0     0
# orphanet.ordo   531    175   54   150   837         0              0   460
# umls           1658   1530  377   811  5175         0            460     0
# omim             29      0    7    20   285         0             24  2820
# omim.ps         107      1    3     2    64         0             94   139
# gard              0      3    1     0     9         0              9    11
# icd10            13      0    1     3    10         0              0    17
# icd10cm          90     23   31   221   570         0            214   979
# icd10pcs          0      0    0     0     0         0              0     0
# icd11             0      0    0     0     0         0              0     0
# icd11.code        0      0    0     0     0         0              0     0
# icd9              0      0    0     0     0         0              0     0
# icd9cm            0      3    1     0     2         0              2     1
# icdo              0      0    0     0     0         0              0     0
#
# target_prefix  omim  omim.ps  gard  icd10  icd10cm  icd10pcs  icd11  \
# source_prefix
# doid             29      107     0     13       90         0      0
# mondo             0        1     3      0       23         0      0
# efo               7        3     1      1       31         0      0
# mesh             20        2     0      3      221         0      0
# ncit            285       64     9     10      570         0      0
# orphanet          0        0     0      0        0         0      0
# orphanet.ordo    24       94     9      0      214         0      0
# umls           2820      139    11     17      979         0      0
# omim              0        3     5      1       58         0      0
# omim.ps           3        0     3      0       16         0      0
# gard              5        3     0      0        2         0      0
# icd10             1        0     0      0       10         0      0
# icd10cm          58       16     2     10        0         0      0
# icd10pcs          0        0     0      0        0         0      0
# icd11             0        0     0      0        0         0      0
# icd11.code        0        0     0      0        0         0      0
# icd9              0        0     0      0        0         0      0
# icd9cm            0        1     2      0        2         0      0
# icdo              0        0     0      0        0         0      0
#
# target_prefix  icd11.code  icd9  icd9cm  icdo
# source_prefix
# doid                    0     0       0     0
# mondo                   0     0       3     0
# efo                     0     0       1     0
# mesh                    0     0       0     0
# ncit                    0     0       2     0
# orphanet                0     0       0     0
# orphanet.ordo           0     0       2     0
# umls                    0     0       1     0
# omim                    0     0       0     0
# omim.ps                 0     0       1     0
# gard                    0     0       2     0
# icd10                   0     0       0     0
# icd10cm                 0     0       2     0
# icd10pcs                0     0       0     0
# icd11                   0     0       0     0
# icd11.code              0     0       0     0
# icd9                    0     0       0     0
# icd9cm                  0     0       0     0
# icdo                    0     0       0     0
# Here's an alternative view on the number of mappings normalized to show percentage gain.
#
# Note:
#
# - `inf` means that there were no mappings before and now there are a non-zero number of
#    mappings
# - `NaN` means there were no mappings before inference and continue to be no mappings after
#    inference
# target_prefix  doid  mondo   efo     mesh    ncit  orphanet  orphanet.ordo  \
# source_prefix
# doid            0.0    1.7   5.0     14.5    11.9       NaN           24.1
# mondo           1.7    0.0  17.1      6.5     2.3       NaN            1.8
# efo             5.0   17.1   0.0      6.2    10.5       NaN           19.6
# mesh           14.5    6.5   6.2      0.0  1551.9       NaN        15000.0
# ncit           11.9    2.3  10.5   1551.9     0.0       NaN         2262.2
# orphanet        NaN    NaN   NaN      NaN     NaN       NaN            NaN
# orphanet.ordo  24.1    1.8  19.6  15000.0  2262.2       NaN            0.0
# umls           24.4    7.9  28.2  81100.0     inf       NaN            5.6
# omim            0.5    0.0   2.2      inf     inf       NaN            0.2
# omim.ps         inf    0.2  13.0      inf     inf       NaN         2350.0
# gard            0.0    0.0   0.3      NaN     inf       NaN           23.7
# icd10           inf    0.0   0.2      inf     inf       NaN            0.0
# icd10cm         2.5    1.4  10.6      inf     inf       NaN            inf
# icd10pcs        NaN    NaN   NaN      NaN     NaN       NaN            NaN
# icd11           0.0    0.0   0.0      NaN     NaN       NaN            0.0
# icd11.code      NaN    NaN   NaN      NaN     NaN       NaN            NaN
# icd9            0.0    0.0   0.0      NaN     NaN       NaN            0.0
# icd9cm          0.0  150.0  20.0      NaN     inf       NaN            inf
# icdo            0.0    0.0   0.0      NaN     NaN       NaN            0.0
#
# target_prefix     umls  omim  omim.ps  gard  icd10  icd10cm  icd10pcs  icd11  \
# source_prefix
# doid              24.4   0.5      inf   0.0    inf      2.5       NaN    0.0
# mondo              7.9   0.0      0.2   0.0    0.0      1.4       NaN    0.0
# efo               28.2   2.2     13.0   0.3    0.2     10.6       NaN    0.0
# mesh           81100.0   inf      inf   NaN    inf      inf       NaN    NaN
# ncit               inf   inf      inf   inf    inf      inf       NaN    NaN
# orphanet           NaN   NaN      NaN   NaN    NaN      NaN       NaN    NaN
# orphanet.ordo      5.6   0.2   2350.0  23.7    0.0      inf       NaN    0.0
# umls               0.0   inf      inf   inf    inf      inf       NaN    NaN
# omim               inf   0.0      inf   inf    inf      inf       NaN    NaN
# omim.ps            inf   inf      0.0   inf    NaN      inf       NaN    NaN
# gard               inf   inf      inf   0.0    NaN      inf       NaN    NaN
# icd10              inf   inf      NaN   NaN    0.0      inf       NaN    NaN
# icd10cm            inf   inf      inf   inf    inf      0.0       NaN    NaN
# icd10pcs           NaN   NaN      NaN   NaN    NaN      NaN       NaN    NaN
# icd11              NaN   NaN      NaN   NaN    NaN      NaN       NaN    0.0
# icd11.code         NaN   NaN      NaN   NaN    NaN      NaN       NaN    NaN
# icd9               NaN   NaN      NaN   NaN    NaN      NaN       NaN    NaN
# icd9cm             inf   NaN      inf   inf    NaN      inf       NaN    NaN
# icdo               NaN   NaN      NaN   NaN    NaN      NaN       NaN    NaN
#
# target_prefix  icd11.code  icd9  icd9cm  icdo
# source_prefix
# doid                  NaN   0.0     0.0   0.0
# mondo                 NaN   0.0   150.0   0.0
# efo                   NaN   0.0    20.0   0.0
# mesh                  NaN   NaN     NaN   NaN
# ncit                  NaN   NaN     inf   NaN
# orphanet              NaN   NaN     NaN   NaN
# orphanet.ordo         NaN   0.0     inf   0.0
# umls                  NaN   NaN     inf   NaN
# omim                  NaN   NaN     NaN   NaN
# omim.ps               NaN   NaN     inf   NaN
# gard                  NaN   NaN     inf   NaN
# icd10                 NaN   NaN     NaN   NaN
# icd10cm               NaN   NaN     inf   NaN
# icd10pcs              NaN   NaN     NaN   NaN
# icd11                 NaN   NaN     NaN   NaN
# icd11.code            NaN   NaN     NaN   NaN
# icd9                  NaN   0.0     NaN   NaN
# icd9cm                NaN   NaN     0.0   NaN
# icdo                  NaN   NaN     NaN   0.0
# ## Landscape Analysis
#
# Before, we looked at the overlaps between each resource. Now, we use that information
# jointly to estimate the number of terms in the landscape itself, and estimate how much
# of the landscape each resource covers.
# This estimates a total of 275,044 unique entities.
#
# - 16,325
#   (5.9%) have
#   at least one mapping.
# - 258,719 (94.1%)
#   are unique to a single resource.
# - 0 (0.0%)
#   appear in all 19 resources.
#
# This estimate is susceptible to several caveats:
#
# - Missing mappings inflates this measurement
# - Generic resources like MeSH contain irrelevant entities that can't be mapped
# Because there are 19 prefixes, there are 524,287 possible overlaps to consider.
# Therefore, a Venn diagram is not possible, so we
# we use an [UpSet plot](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4720993)
# (Lex *et al.*, 2014) as a high-dimensional Venn diagram.
# We now aggregate the mappings together to estimate the number of unique entities and number
# that appear in each group of resources.
# \
#         The landscape of 19 resources has 377,250 total terms.
#         After merging redundant nodes based on mappings, inference, and reasoning, there
#         are 275,044 unique concepts. Using the reduction formula
#         $\frac{\text{total terms} - \text{reduced terms}}{\text{total terms}}$,
#         this is a 27.1% reduction.
# This is only an estimate and is susceptible to a few things:
#
# 1. It can be artificially high because there are entities that _should_ be mapped, but are not
# 2. It can be artificially low because there are entities that are incorrectly mapped, e.g., as
#    a result of inference. The frontend curation interface can help identify and remove these
# 3. It can be artificially low because for some vocabularies like SNOMED-CT, it's not possible
#    to load a terms list, and therefore it's not possible to account for terms that aren't
#    mapped. Therefore, we make a lower bound estimate based on the terms that appear in
#    mappings.
# 4. It can be artificially high if a vocabulary is used that covers many domains and is not
#    properly subset'd. For example, EFO covers many different domains, so when doing disease
#    landscape analysis, it should be subset to only terms in the disease hierarchy
#    (i.e., appearing under ``efo:0000408``).
# 5. It can be affected by terminology issues, such as the confusion between Orphanet and ORDO
# 6. It can be affected by the existence of many-to-many mappings, which are filtered out during
#    processing, which makes the estimate artificially high since some subset of those entities
#    could be mapped, but it's not clear which should.
