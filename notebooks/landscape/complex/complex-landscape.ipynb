# %%
from semra.landscape.complexes import CONFIGURATION
from semra.landscape.utils import notebook

# %%
_ = notebook(CONFIGURATION, output_directory=".", minimum_count=1)
# Out:
# [go] parsing edges:   0%|                                                                                                    | 0.00/148k [00:00<?, ?edge/s]
# [go] parsing edges:   3%|██▋                                                                                        | 4.33k/148k [00:00<00:04, 28.9kedge/s]
# [go] parsing edges:  10%|█████████▍                                                                                 | 15.4k/148k [00:00<00:02, 46.5kedge/s]
# [go] parsing edges:  20%|█████████████████▊                                                                         | 29.1k/148k [00:00<00:02, 53.5kedge/s]
# [go] parsing edges:  30%|███████████████████████████▍                                                               | 44.8k/148k [00:00<00:01, 79.0kedge/s]
# [go] parsing edges:  37%|█████████████████████████████████▏                                                         | 54.2k/148k [00:00<00:01, 55.3kedge/s]
# ...
